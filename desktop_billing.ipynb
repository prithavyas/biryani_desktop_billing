# %% [markdown]
# <a href="https://colab.research.google.com/github/prithavyas/biryani_desktop_billing/blob/main/desktop_billing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name_person = 'Name'
phone_no = 'Contact Number'
food_item_no = 'Food Item No'
b_name = 'Biryani Name'
Quantity_biryani = 'Quantity'

def billing_system(name, contact, Food_id, biryani_name, qty, cost):
    print('-' * 60)
    print('\t\t\t KK BIRYANI \t\t\t\t')
    print('-' * 60)
    print(f"{name_person.upper()}\t\t\t\t{name}")
    print('-' * 60)
    print(f"{phone_no.upper()}\t\t\t\t{contact}")
    print('-' * 60)
    print(f"{food_item_no.upper()}\t\t\t\t{Food_id}")
    print('-' * 60)
    print(f"{b_name.upper()}\t\t\t\t{biryani_name}")
    print('-' * 60)
    print(f"{Quantity_biryani.upper()}\t\t\t\t{qty}")
    print('-' * 60)
    print('-' * 60)
    print(f"TOTAL \t\t\t\t{cost}")
    print('\n')

name = input('Enter the name of the customer: ')
contact = int(input('Enter the customer contact number: '))

total_cost = 0
while True:
    Food_id = int(input('Enter the food id (Enter 0 to stop): '))

    if Food_id == 0:
        break

    if Food_id == 1:
        biryani_name = 'Chicken Biryani'
        cost = 170.00
    elif Food_id == 2:
        biryani_name = 'Chicken Biryani'
        cost = 180.00
    elif Food_id == 3:
        biryani_name = 'Chicken Biryani'
        cost = 110.00
    elif Food_id == 4:
        biryani_name = 'Kushka'
        cost = 80.00
    elif Food_id == 5:
        biryani_name = 'Kushka'
        cost = 170.00
    elif Food_id == 6:
        biryani_name = 'Kushka'
        cost = 50.00
    elif Food_id == 7:
        biryani_name = 'Egg Biryani'
        cost = 140.00
    elif Food_id == 8:
        biryani_name = 'Egg Biryani'
        cost = 100.00
    elif Food_id == 9:
        biryani_name = 'Mutton Biryani'
        cost = 190.00
    elif Food_id == 10:
        biryani_name = 'Mutton Biryani'
        cost = 130.00
    else:
        print('Invalid ID')
        continue

    qty = int(input('Enter the quantity: '))
    item_cost = cost * qty
    total_cost += item_cost

    billing_system(name, contact, Food_id, biryani_name, str(qty) + ' kg', item_cost)

print(f'Total Bill Amount: {total_cost}')
# Out:
# Enter the name of the customer: pritha vyas
# Enter the customer contact number: 6376623609
# Enter the food id (Enter 0 to stop): 5
# Enter the quantity: 3
# ------------------------------------------------------------
# 			 KK BIRYANI
# ------------------------------------------------------------
# NAME				pritha vyas
# ------------------------------------------------------------
# CONTACT NUMBER				6376623609
# ------------------------------------------------------------
# FOOD ITEM NO				5
# ------------------------------------------------------------
# BIRYANI NAME				Kushka
# ------------------------------------------------------------
# QUANTITY				3 kg
# ------------------------------------------------------------
# ------------------------------------------------------------
# TOTAL 				510.0
#
#
# Enter the food id (Enter 0 to stop): 6
# Enter the quantity: 2
# ------------------------------------------------------------
# 			 KK BIRYANI
# ...
